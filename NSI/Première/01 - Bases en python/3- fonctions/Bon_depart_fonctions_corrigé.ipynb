# %% [markdown]
# <center><font color="lightseagreen" size="5"><b> ⚠️⚠️⚠️   &nbsp; &nbsp;! Pensez à faire une copie <u>dans votre Drive</u> avant de commencer !  &nbsp; &nbsp;⚠️⚠️⚠️</b></font></center>

# %% [markdown]
# <font color="lightseagreen" size="6"><b> NSI 1ère   Bon départ avec les fonctions en Python</b></font>

# %% [markdown]
# ---
#
# ---
# <font color="lightseagreen" size="5"><b> I. Première situation : </b></font>
#
# ---
#
# ---

# %% [markdown]
# ![512px-Chair-O-Planes,_night.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# <font color="lightseagreen" size="5"><b> I.1. La caisse est tombée en panne</b></font> 😪
# Le droit d'entrée journalier dans un parc d’attraction est de 37€ pour un adulte et de 28€ pour un enfant.
# Alice et Bob doivent faire payer les entrées, mais leur caisse est malheureusement tombée en panne, et la queue s’allonge très vite…
# On leur fourni en urgence une calculatrice qui dispose de Python pour les aider.
#
# Un groupe de 2 adultes et 2 enfants se présente à la caisse. Il faut donc calculer :   $2 \times 37 + 2 \times 28$
# Un groupe de 3 adultes et 5 enfants se présente à la caisse. Il faut donc calculer :    $3 \times 37 + 5 \times 28$
# Un groupe de 1 adulte et 3 enfants se présente à la caisse. Il faut donc calculer :    $1 \times 37 + 3 \times 28$
# Ces calculs sont très répétitifs, et prennent du temps. La queue continue à s’allonger …
# Ils remarquent qu’il suffirait de saisir le nombre d’adultes et le nombre d’enfants pour automatiser le calcul. Ils décident d’écrire une fonction en Python :
# Exécuter ce script.

# %%
def prix(nbre_adultes, nbre_enfants):
    resultat = 37 * nbre_adultes + 28 * nbre_enfants
    return resultat

# %% [markdown]
# Que s'est-il passé ?  Double cliquer ici pour répondre.
# Réponse : On a défini une fonction prix, mais on ne l'a pas appelée, donc pas exécutée.

# %%
prix(3, 2)
# Out:
# 167

# %% [markdown]
# Exécuter maintenant :

# %%
prix(2, 3) 
print('fin')

# %% [markdown]
# Pourquoi le résultat ne s'affiche pas dans ce dernier cas ?

# %% [markdown]
# Réponse : parce qu'on a jamais demandé de l'afficher !
#
# Dans le  code précédent il s'affiche seulement parce que il est à la fin du code, et dans une cellule de code, tout comme dans la console, le résutat de la dernière instruction est affiché. Mais en réalité, **la fonction n'affiche rien et l'appel de la fonction non plus.**

# %% [markdown]
# Faire d'autres essais ci-dessous:

# %%
# Vos essais :

# %% [markdown]
# Si on **« appelle »** `prix(3, 2)` :
# •	3 est automatiquement affecté à la variable  `nbre_adultes`
# •	2 est automatiquement affecté à la variable  `nbre_enfants`

# %% [markdown]
# <font  color="blue" size="4">👉 Alice et Bob ont créé la **fonction** dont le **nom** est `prix`, qui a deux **paramètres** `nbre_adultes` et `nbre_enfants`.</font>

# %% [markdown]
# <font color="lightseagreen" size="5"><b> I.2 La situation d’Alice et Bob s'améliore</b></font>  😊
#
# La situation d’Alice et Bob s’est nettement améliorée, mais ils veulent aller encore plus vite.
# Ils voudraient juste saisir les nombres d’adultes et d’enfants, par exemple 3 et 2 , et ne pas avoir à écrire `prix(3,2)`
# Pour cela, ils écrivent le script suivant :
# Exécuter ce script.

# %%
def prix(nbre_adultes, nbre_enfants):
    resultat = 37  *nbre_adultes + 28 * nbre_enfants
    return resultat

adultes = int(input("nombre d adultes ?"))
enfants = int(input("nombre d enfants ?"))
a_payer = prix(adultes, enfants)
print("A payer : ",a_payer)

# %% [markdown]
# <font  color="blue" size="4">👉La fonction `prix` a été appelée. Le résultat renvoyé par la fonction a été affecté à la variable `a_payer`. Cette variable a ensuite été affichée.</font>

# %% [markdown]
# <font color="lightseagreen" size="5"><b> I.3. Le tarif étudiant</b></font>  😊
#
# On vient signaler à Alice et Bob qu’un nouveau tarif entre en vigueur instantanément : le tarif « étudiant » à 30€.
#
# ## 💻 A vous de jouer 1 :
# En vous inspirant de ce que vous avez déjà vu, écrire un script qui tienne compte de ce nouveau tarif.
# Le tester pour 1 adulte, 2 étudiants, 3 enfants. Le prix à payer doit être 181 €.

# %%
def prix(nbre_adultes, nbre_enfants, nbre_etudiants):
    resultat = 37  *nbre_adultes + 28 * nbre_enfants + 30 * nbre_etudiants
    return resultat

adultes = int(input("nombre d adultes ?"))
etudiants = int(input("nombre d etudiants ?"))
enfants = int(input("nombre d enfants ?"))
a_payer = prix(adultes, enfants, etudiants)
print("A payer : ",a_payer)
# Out:
# nombre d adultes ?1
# nombre d etudiants ?2
# nombre d enfants ?3
# A payer :  181

# %% [markdown]
# <font color="lightseagreen" size="5"><b> I.4. 🎂 Jour d'anniversaire</b></font>
#
# Nouveauté : si c’est le jour d’anniversaire d’une personne du groupe, tout le groupe bénéficie d’une réduction de 10 %.
# ## 💻 A vous de jouer 2 :
# Sans modifier la fonction du 3., compléter le programme pour qu’il demande si c’est un jour anniversaire, et qu’il affiche le prix à payer suivant les cas.
# On rappelle que pour diminuer un prix de 10%, il suffit de le multiplier par 0.9.

# %%
# Recopier votre code du 3. ici, puis le compléter

# %% [markdown]
# ---
#
# ---
# <font color="lightseagreen" size="5"><b> I. Deuxème situation : </b></font>
#
# ---
#
# ---

# %% [markdown]
# Le petit frère de Bob doit apprendre ses tables de multiplication.
# Pensant l’aider, Bob écrit la fonction suivante :
# Exécuter ce script.

# %%
def table_mult(nbre):
    for i in range(1, 11):
        return i * nbre

print(table_mult(9))
# Out:
# 9

# %% [markdown]
# Que s'est-il passé ?
# **Réponse :** Dès qu'on rencontre l'instruction **return** la fonction s'arrête. Ici, dès la première itération, avec i=1, on renvoie i * nbre (c'est-à-dire 9)

# %% [markdown]
# <font  color="blue" size="4">👉A noter : losque l'on renconter l'instruction `return`, on sort de la fonction.
# Si un `return` se trouve dans une boucle `for`, on sort donc dès le 1er tour de boucle effectué.</font>

# %% [markdown]
# Nous verrons dans le paragraphe IV. comment on peut faire.
# Mais d'abrd, regardons si une fonction peut renvoyer plusieurs choses.

# %% [markdown]
# <font color="lightseagreen" size="5"><b> III. Et si l'on veut que notre fonction renvoie plusieurs résultats ? </b></font>

# %% [markdown]
# Vous rencontrerez souvent des fonctions comme celle se trouvant dans le script ci-dessous :
# Exécuter ce script. Que s'affiche-t-il ?

# %%
def somme_prod(nbre1, nbre2):
    return nbre1 + nbre2, nbre1 * nbre2

resultat = somme_prod(2, 5)
print(resultat)
print(type(resultat))

# %% [markdown]
# Vous observez que des parenthèses sont apparues dans l’affichage du résultat. En fait il y a une seule variable retournée, et non deux, qui est de type tuple (ici un “couple” de deux entiers), comme l’affichage de la ligne suivante le confirme. Nous étudierons plus tard les tuples.

# %% [markdown]
# <font color="lightseagreen" size="5"><b> IV. Comment créer une fonction qui nous donne une table de multiplication ? </b></font>
# ## Méthode 1 :
#
#
# On écrit une fonction qui renvoie une « liste » ou un « tuple. »
# Une telle fonction renverra par exemple pour la table de 9
# •	Si la fonction renvoie une liste : [9, 18, 27, 36, 45, 54, 63, 72, 81, 90]
# •	Si la fonction renvoie un tuple : (9, 18, 27, 36, 45, 54, 63, 72, 81, 90)

# %% [markdown]
# ## Méthode 2 : avec une procédure :
# On peut écrire une fonction qui ne renvoie rien, mais qui fait des actions, comme par exemple des affichages.

# %% [markdown]
# <font  color="blue" size="4">👉 Une fonction qui ne renvoie rien s’appelle une procédure.</font>

# %% [markdown]
# Exécuter le script ci-dessous.
# Que s’affiche-t-il?

# %%
def table_mult(nbre):
    for i in range(1, 11):
        print(i * nbre)
    return None


table_mult(9)
# Out:
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81
# 90

# %% [markdown]
# ## 💻 A vous de jouer 3 :
# Modifier le script en supprimant la ligne return None. (Vous pouvez juste écrire un # devant la ligne)
# Que s’est-il passé ?

# %%
# Votre code :

# %% [markdown]
# <font  color="blue" size="4">👉 Dans une procédure, la ligne `return None` est facultative </font>

# %% [markdown]
# <font color="lightseagreen" size="5"><b> V. Une fonction sans paramètre ? </b></font>

# %% [markdown]
# Tester le programme suivant :

# %%
from random import randint

def jouer():
    return randint(1, 6)

for i in range(10):
    lancer = jouer()
    print(lancer)
# Out:
# 3
# 4
# 6
# 2
# 2
# 4
# 3
# 4
# 4
# 3

# %% [markdown]
# <font size="6" >&#9997; </font> <strong>A noter :
# <font  color="blue">
# - Une fonction commence par le mot `def` , suivi du nom de la fonction, de la liste des paramètres entre parenthèses, et de  `:`    .
# - Toutes les instructions d’une fonction sont indentées.
# - S’il n’y a pas de paramètres, il faut obligatoirement mettre des parenthèses vides.
# - Une fonction ne peut renvoyer qu’une seule variable. Cela se fait avec l’instruction `return` .
# - L’exécution de l’instruction `return` provoque obligatoirement la sortie de la fonction. Si d’autres instructions se trouvent après `return` elles ne seront jamais exécutées.
# - La valeur renvoyée est indiquée par l’instruction (optionnelle) `return`. Si celle-ci n’est pas présente, la valeur par défaut `None` est renvoyée.</font>
# </strong>

# %% [markdown]
# <font color="lightseagreen" size="5"><b> VI. 🤔 Appeler une fonction dans une fonction ... </b></font>

# %% [markdown]
# ## 1.	Exécuter le script suivant :
# La fonction euro_vers_yan appelle deux autres fonctions. Cela ne pose aucun problème.

# %%
def euro_vers_dollar(euros):
    return euros * 1.19 # en supposant qu'un euro vaut 1,19 dollars

def dollar_vers_yuan(dollars):
    return dollars * 6.93 # en supposant qu'un dollar vaut 6,93 yuans

def euro_vers_yuan(montant):
    # Appel de la fonction euro_vers_dollar
    montant_dollar = euro_vers_dollar(montant)
    # Appel de la fonction dollar_vers_yuan
    montant_yuan = dollar_vers_yuan(montant_dollar)
    # Valeur renvoyee
    return montant_yuan

euros = float(input("entrez le montant en euros :"))
montant_converti = euro_vers_yuan(euros)
print(euros,"€ représente ",montant_converti,"yuan")
# Out:
# entrez le montant en euros :2
# 2.0 € représente  16.493399999999998 yuan

# %% [markdown]
# <center>
#
# ---
#
# **Auteur** Mireille Coilhac & Jean-Louis Thirot
#
# Publié sous licence CC BY-NC-SA
#
#
# ---
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" width="200" src="https://s2.qwant.com/thumbr/700x0/f/9/436dcce5e02185c0b2e1b0e7a969aa81d7b0438d0a7f2eaee89abb9661b70b/cc-by-nc-sa.svg_.png?u=http%3A%2F%2Fopensiddur.org%2Fwp-content%2Fuploads%2F2011%2F03%2Fcc-by-nc-sa.svg_.png&q=0&b=1&p=0&a=1" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.
